# %%
import numpy as np
import pandas as pd
from datetime import datetime

seagull = pd.read_csv('bird_tracking.csv')

# %%
seagull.head()

display(seagull['longitude'].min())
display(seagull['longitude'].max())
display(seagull['latitude'].min())
display(seagull['latitude'].max())
# Out:
# -17.6261451
# 4.8575613
# 12.354424
# 51.5184521

# %%
seagull.dtypes
# Out:
# Unnamed: 0              int64
# altitude                int64
# date_time              object
# device_info_serial      int64
# direction             float64
# latitude              float64
# longitude             float64
# speed_2d              float64
# bird_name              object
# dtype: object

# %%
seagull['bird_name'].unique()
# Out:
# array(['Eric', 'Nico', 'Sanne'], dtype=object)

# %%
eric = seagull[seagull['bird_name'] == 'Eric'].reset_index(drop=True)
nico = seagull[seagull['bird_name'] == 'Nico'].reset_index(drop=True)
sanne = seagull[seagull['bird_name'] == 'Sanne'].reset_index(drop=True)

sanne.head(100)
# Out:
#     Unnamed: 0  altitude               date_time  device_info_serial  \
# 0        40916        55  2013-08-15 00:01:08+00                 833
# 1        40917        54  2013-08-15 00:31:00+00                 833
# 2        40918        55  2013-08-15 01:01:19+00                 833
# 3        40919        56  2013-08-15 01:31:38+00                 833
# 4        40920        55  2013-08-15 02:01:24+00                 833
# ..         ...       ...                     ...                 ...
# 95       41011        38  2013-08-16 04:53:39+00                 833
# 96       41012        37  2013-08-16 05:08:34+00                 833
# 97       41013        37  2013-08-16 05:23:29+00                 833
# 98       41014        49  2013-08-16 05:38:25+00                 833
# 99       41015        35  2013-08-16 05:53:22+00                 833
#
#      direction   latitude  longitude  speed_2d bird_name
# 0   -91.499509  49.931065   2.281893  0.372156     Sanne
# ...

# %%
eric.to_csv(r"./eric")
nico.to_csv(r"./nico")
sanne.to_csv(r"./sanne")

# %%
eric
# Out:
#        Unnamed: 0  altitude               date_time  device_info_serial  \
# 0               0        71  2013-08-15 00:18:08+00                 851
# 1               1        68  2013-08-15 00:48:07+00                 851
# 2               2        68  2013-08-15 01:17:58+00                 851
# 3               3        73  2013-08-15 01:47:51+00                 851
# 4               4        69  2013-08-15 02:17:42+00                 851
# ...           ...       ...                     ...                 ...
# 19790       19790        12  2014-04-30 21:51:26+00                 851
# 19791       19791        34  2014-04-30 22:21:33+00                 851
# 19792       19792         1  2014-04-30 22:51:41+00                 851
# 19793       19793         7  2014-04-30 23:21:34+00                 851
# 19794       19794        16  2014-04-30 23:51:29+00                 851
#
#         direction   latitude  longitude  speed_2d bird_name
# ...
